# %%
import os
import pickle
from multiprocessing import Pool

import numpy as np
import tensorflow as tf
import pandas as pd
from tqdm.auto import tqdm
import json

# %% [markdown]
# ## Helper functions

# %%
def to_feature(value, dtype):
    if dtype in ['int', 'int64', 'uint32', 'uint64', 'bool', 'enum']:
        return tf.train.Feature(int64_list=tf.train.Int64List(value=value))
    
    if dtype in ['float', 'double', 'float32', 'float64']:
        return tf.train.Feature(float_list=tf.train.FloatList(value=value))
    
    if dtype in ['string', 'bytes']:
        return tf.train.Feature(bytes_list=tf.train.BytesList(value=value))
    
    else:
        error_msg = (
            f"dtype '{dtype}' not recognized. You need to use a dtype compatible with TF protos."
            "See: https://www.tensorflow.org/tutorials/load_data/tfrecord"
        )
        raise ValueError(error_msg)

def to_example(feature):
    return tf.train.Example(features=tf.train.Features(feature=feature))

def serialize(example):
    return example.SerializeToString()

def deserialize(string):
    return tf.train.Example.FromString(string)

# %% [markdown]
# ## Initialize Kaggle Dataset Metadata

# %%
os.makedirs('/kaggle/dataset/', exist_ok=True)

# Change below
meta = dict(
    id="tft/seti-tfrecords-train",
    title="SETI Train Split in TF Records",
    isPrivate=True,
    licenses=[dict(name="other")]
)

with open('/kaggle/dataset/dataset-metadata.json', 'w') as f:
    json.dump(meta, f)

# %% [markdown]
# ## Start generating TF Records

# %%
labels = pd.read_csv('../input/seti-breakthrough-listen/train_labels.csv')

# %%
split = 'train'
n_jobs = 8

N = labels.shape[0]
chunk_size = np.ceil(N / (n_jobs * 10)).astype(int)
indices = np.arange(0, N, chunk_size)

# %%
def write_record(arg):
    chunk, idx, chunk_size, split = arg
    
    record_path = f"/kaggle/dataset/{split}-{chunk}.tfrecord"
    chunk_df = labels.values[idx: idx+chunk_size]
    
    print("Starting to write", record_path)
    with tf.io.TFRecordWriter(record_path) as writer:
        for idx, target in chunk_df:
            path = os.path.join("../input/seti-breakthrough-listen", split, idx[0], idx + '.npy')
            X = np.load(path)
            y = target

            feature = {
                "X": to_feature(X.flatten(), 'float'),
                "y": to_feature([y], 'int')
            }

            example = to_example(feature)
            serialized = serialize(example)
            writer.write(serialized)
        
    print("Finished to write", record_path)

# %%
args = [
    (chunk, idx, chunk_size, split)
    for chunk, idx in enumerate(indices)
]

# %%
# %%time
with Pool(4) as p:
    p.map(write_record, args)
# Out:
# Starting to write /kaggle/dataset/train-0.tfrecord
# Starting to writeStarting to write Starting to write /kaggle/dataset/train-15.tfrecord/kaggle/dataset/train-5.tfrecord
# /kaggle/dataset/train-10.tfrecord
#
# Finished to write /kaggle/dataset/train-15.tfrecord
# Starting to write /kaggle/dataset/train-16.tfrecord
# Finished to write /kaggle/dataset/train-0.tfrecord
# Starting to write /kaggle/dataset/train-1.tfrecord
# Finished to write /kaggle/dataset/train-10.tfrecord
# Starting to write /kaggle/dataset/train-11.tfrecord
# Finished to write /kaggle/dataset/train-5.tfrecord
# Starting to write /kaggle/dataset/train-6.tfrecord
# Finished to write /kaggle/dataset/train-6.tfrecord
# Starting to write /kaggle/dataset/train-7.tfrecord
# Finished to write /kaggle/dataset/train-1.tfrecord
# Starting to write /kaggle/dataset/train-2.tfrecord
# Finished to write /kaggle/dataset/train-16.tfrecord
# Starting to write /kaggle/dataset/train-17.tfrecord
# Finished to write /kaggle/dataset/train-11.tfrecord
# Starting to write /kaggle/dataset/train-12.tfrecord
# Finished to write /kaggle/dataset/train-17.tfrecord
# Starting to write /kaggle/dataset/train-18.tfrecord
# Finished to write /kaggle/dataset/train-2.tfrecord
# Starting to write /kaggle/dataset/train-3.tfrecord
# Finished to write /kaggle/dataset/train-12.tfrecord
# Starting to write /kaggle/dataset/train-13.tfrecord
# Finished to write /kaggle/dataset/train-7.tfrecord
# Starting to write /kaggle/dataset/train-8.tfrecord
# Finished to write /kaggle/dataset/train-3.tfrecord
# Starting to write /kaggle/dataset/train-4.tfrecord
# Finished to write /kaggle/dataset/train-18.tfrecord
# Starting to write /kaggle/dataset/train-19.tfrecord
# Finished to write /kaggle/dataset/train-8.tfrecord
# Starting to write /kaggle/dataset/train-9.tfrecord
# Finished to write /kaggle/dataset/train-13.tfrecord
# Starting to write /kaggle/dataset/train-14.tfrecord
# Finished to write /kaggle/dataset/train-19.tfrecord
# Starting to write /kaggle/dataset/train-20.tfrecord
# Finished to write /kaggle/dataset/train-4.tfrecord
# Starting to write /kaggle/dataset/train-25.tfrecord
# Finished to write /kaggle/dataset/train-14.tfrecord
# Starting to write /kaggle/dataset/train-30.tfrecord
# Finished to write /kaggle/dataset/train-9.tfrecord
# Starting to write /kaggle/dataset/train-35.tfrecord
# Finished to write /kaggle/dataset/train-25.tfrecord
# Starting to write /kaggle/dataset/train-26.tfrecord
# Finished to write /kaggle/dataset/train-30.tfrecord
# Starting to write /kaggle/dataset/train-31.tfrecord
# Finished to write /kaggle/dataset/train-20.tfrecord
# Starting to write /kaggle/dataset/train-21.tfrecord
# Finished to write /kaggle/dataset/train-35.tfrecord
# Starting to write /kaggle/dataset/train-36.tfrecord
# Finished to write /kaggle/dataset/train-26.tfrecord
# Starting to write /kaggle/dataset/train-27.tfrecord
# Finished to write /kaggle/dataset/train-31.tfrecord
# Starting to write /kaggle/dataset/train-32.tfrecord
# Finished to write /kaggle/dataset/train-36.tfrecord
# Starting to write /kaggle/dataset/train-37.tfrecord
# Finished to write /kaggle/dataset/train-21.tfrecord
# Starting to write /kaggle/dataset/train-22.tfrecord
# Finished to write /kaggle/dataset/train-32.tfrecord
# Starting to write /kaggle/dataset/train-33.tfrecord
# Finished to write /kaggle/dataset/train-27.tfrecord
# Starting to write /kaggle/dataset/train-28.tfrecord
# Finished to write /kaggle/dataset/train-37.tfrecord
# Starting to write /kaggle/dataset/train-38.tfrecord
# Finished to write /kaggle/dataset/train-22.tfrecord
# Starting to write /kaggle/dataset/train-23.tfrecord
# Finished to write /kaggle/dataset/train-33.tfrecord
# Starting to write /kaggle/dataset/train-34.tfrecord
# Finished to write /kaggle/dataset/train-28.tfrecord
# Starting to write /kaggle/dataset/train-29.tfrecord
# Finished to write /kaggle/dataset/train-38.tfrecord
# Starting to write /kaggle/dataset/train-39.tfrecord
# Finished to write /kaggle/dataset/train-23.tfrecord
# Starting to write /kaggle/dataset/train-24.tfrecord
# Finished to write /kaggle/dataset/train-34.tfrecord
# Starting to write /kaggle/dataset/train-40.tfrecord
# Finished to write /kaggle/dataset/train-29.tfrecord
# Starting to write /kaggle/dataset/train-45.tfrecord
# Finished to write /kaggle/dataset/train-39.tfrecord
# Starting to write /kaggle/dataset/train-50.tfrecord
# Finished to write /kaggle/dataset/train-24.tfrecord
# Starting to write /kaggle/dataset/train-55.tfrecord
# Finished to write /kaggle/dataset/train-40.tfrecord
# Starting to write /kaggle/dataset/train-41.tfrecord
# Finished to write /kaggle/dataset/train-45.tfrecord
# Starting to write /kaggle/dataset/train-46.tfrecord
# Finished to write /kaggle/dataset/train-50.tfrecord
# Starting to write /kaggle/dataset/train-51.tfrecord
# Finished to write /kaggle/dataset/train-55.tfrecord
# Starting to write /kaggle/dataset/train-56.tfrecord
# Finished to write /kaggle/dataset/train-46.tfrecord
# Starting to write /kaggle/dataset/train-47.tfrecord
# Finished to write /kaggle/dataset/train-41.tfrecord
# Starting to write /kaggle/dataset/train-42.tfrecord
# Finished to write /kaggle/dataset/train-51.tfrecord
# Starting to write /kaggle/dataset/train-52.tfrecord
# Finished to write /kaggle/dataset/train-56.tfrecord
# Starting to write /kaggle/dataset/train-57.tfrecord
# Finished to write /kaggle/dataset/train-47.tfrecord
# Starting to write /kaggle/dataset/train-48.tfrecord
# Finished to write /kaggle/dataset/train-42.tfrecord
# Starting to write /kaggle/dataset/train-43.tfrecord
# Finished to write /kaggle/dataset/train-52.tfrecord
# Starting to write /kaggle/dataset/train-53.tfrecord
# Finished to write /kaggle/dataset/train-57.tfrecord
# Starting to write /kaggle/dataset/train-58.tfrecord
# Finished to write /kaggle/dataset/train-48.tfrecord
# Starting to write /kaggle/dataset/train-49.tfrecord
# Finished to write /kaggle/dataset/train-43.tfrecord
# Starting to write /kaggle/dataset/train-44.tfrecord
# Finished to write /kaggle/dataset/train-53.tfrecord
# Starting to write /kaggle/dataset/train-54.tfrecord
# Finished to write /kaggle/dataset/train-58.tfrecord
# Starting to write /kaggle/dataset/train-59.tfrecord
# Finished to write /kaggle/dataset/train-49.tfrecord
# Starting to write /kaggle/dataset/train-60.tfrecord
# Finished to write /kaggle/dataset/train-44.tfrecord
# Starting to write /kaggle/dataset/train-65.tfrecord
# Finished to write /kaggle/dataset/train-54.tfrecord
# Starting to write /kaggle/dataset/train-70.tfrecord
# Finished to write /kaggle/dataset/train-59.tfrecord
# Starting to write /kaggle/dataset/train-75.tfrecord
# Finished to write /kaggle/dataset/train-60.tfrecord
# Starting to write /kaggle/dataset/train-61.tfrecord
# Finished to write /kaggle/dataset/train-70.tfrecord
# Starting to write /kaggle/dataset/train-71.tfrecord
# Finished to write /kaggle/dataset/train-65.tfrecord
# Starting to write /kaggle/dataset/train-66.tfrecord
# Finished to write /kaggle/dataset/train-75.tfrecord
# Starting to write /kaggle/dataset/train-76.tfrecord
# Finished to write /kaggle/dataset/train-61.tfrecord
# Starting to write /kaggle/dataset/train-62.tfrecord
# Finished to write /kaggle/dataset/train-71.tfrecord
# Starting to write /kaggle/dataset/train-72.tfrecord
# Finished to write /kaggle/dataset/train-66.tfrecord
# Starting to write /kaggle/dataset/train-67.tfrecord
# Finished to write /kaggle/dataset/train-76.tfrecord
# Starting to write /kaggle/dataset/train-77.tfrecord
# Finished to write /kaggle/dataset/train-62.tfrecord
# Starting to write /kaggle/dataset/train-63.tfrecord
# Finished to write /kaggle/dataset/train-72.tfrecord
# Starting to write /kaggle/dataset/train-73.tfrecord
# Finished to write /kaggle/dataset/train-67.tfrecord
# Starting to write /kaggle/dataset/train-68.tfrecord
# Finished to write /kaggle/dataset/train-77.tfrecord
# Starting to write /kaggle/dataset/train-78.tfrecord

# %% [markdown]
# ## Upload dataset

# %%
# !kaggle datasets version -p "/kaggle/dataset" -m "Updated via notebook" --dir-mode zip

# %% [markdown]
# ## Code for reading TF Records

# %%
def parse_train_example(example):
    feature_description = {
        "X": tf.io.FixedLenFeature((6, 273, 256), tf.float32),
        "y": tf.io.FixedLenFeature([], tf.int64)
    }

    example = tf.io.parse_single_example(example, feature_description)
    X = tf.transpose(example['X'], (0, 2, 1))
    
    return X, example['y']

def parse_test_example(example):
    feature_description = {
        "X": tf.io.FixedLenFeature((6, 273, 256), tf.float32)
    }

    example = tf.io.parse_single_example(example, feature_description)
    X = tf.transpose(example['X'], (0, 2, 1))
    
    return X


parsed_dataset = (
    tf.data.TFRecordDataset([f"/kaggle/dataset/train-{chunk}.tfrecord" for chunk in range(4)])
    .map(parse_train_example)
)
